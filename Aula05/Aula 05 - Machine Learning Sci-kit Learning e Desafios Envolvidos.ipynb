# %% [markdown]
# <a href="https://colab.research.google.com/github/lgbizzi/Imersao_Dados_Alura/blob/main/Aula05/Aula%2005%20-%20Machine%20Learning%20Sci-kit%20Learning%20e%20Desafios%20Envolvidos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
 dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados.tail
# Out:
# <bound method NDFrame.tail of                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 últimas linhas da tabela
#
# ###Desafio 03: Calcular a proporção das classes tratamento. (Investigando a documentação do Pandas, dica: usar o value_counts)
#
# ###Desafio 04: Quantos tipos de drogas foram investigados?
#
# ###Desafio 05: Procurar na Documentação do pandas o método query.
#
# ###Desafio 06: Renomear as colunas tirando o hífen.
#
# ###Desafio 07: Deixar os gráficos bonitões (título, label e etc, procurando no Matplotlib.pyplot)
#
# ###Desafio 08: Resumo do que você aprendeu com os Dados.

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
mapa = {'droga' : 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados['composto'].value_counts()

import seaborn as sns

sns.countplot(x = 'composto', data=dados)

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100)

# %%
dados['g-19'].hist(bins = 100)

# %%
dados['g-0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']]
dados.loc[: ,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[: ,'g-0':'g-771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[: ,'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[: ,'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[: ,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x = 'g-0', data = dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y = 'g-0', x='tratamento', data = dados)

# %% [markdown]
# ###Aula 02
#
# ###Desafio 01: Ordenar o gráfico countplot
# ###Desafio 02: Melhorar a visualização alterando o tamanho da fonte...
# ###Desafio 03: Plottar os histogramas com o Seaborn;
# ###Desafio 04: Estudar sobre as estatísticas retornadas no método describe()
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações
# ###Desafio 06: Fazer outras análises com o boxplot e até com o histograma (Dica: Olhar no Seaborn como plottar 2 histogramas juntos, como foi com o boxplot);

# %%
dados.head()
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y='g-8', data=dados)

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color': 'red'})

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color': 'red'}, col='tratamento')

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %%
dados.loc[:, 'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np

corr = dados.loc[:, 'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:, 'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ###Aula 03
#
# ###Desafio 01: Criar tabelas de frequência com pandas.groupby()
#
# ###Desafio 02: Normalizar o crosstab pela Coluna.
#
# ###Desafio 03: Explorar outros agregadores.
#
# ###Desafio 04: Explorar o melt.
#
# ###Desafio 05: Calcular e analisar a correlação entre os G e C. (Dica: perceber que está sendo plotada uma matriz quadrada e definir como fazer o heatmap disso). Refletir sobre os efeitos biológicos.
#
# ###Desafio 06: Estudar o código que plota a matriz de correlação (heatmap).
#
# ###Desafio 07: Resumo do que você aprendeu com os dados.

# %% [markdown]
# ###**Desafio 01:**
# Criar tabelas de frequência com pandas.groupby()

# %%
dados.groupby(by = ['tratamento', 'dose', 'tempo'], as_index=True).count()['id']
# Out:
# tratamento    dose  tempo
# com_controle  D1    24        301
#                     48        343
#                     72        307
#               D2    24        305
#                     48        305
#                     72        305
# com_droga     D1    24       3585
#                     48       4011
#                     72       3600
#               D2    24       3581
#                     48       3591
#                     72       3580
# Name: id, dtype: int64

# %% [markdown]
# ###**Desafio 02:**
# Normalizar o crosstab pela Coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# Quando passamos o valor 'index' para o normalize, indicamos para o crosstab que normalize os valores conforme as linhas.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %% [markdown]
# Porém, Quando passamos o valor 'True' para o normalize, o crosstab normaliza por colunas por padrão da função.

# %% [markdown]
# ###**Desafio 03:**
# Explorar outros agregadores:

# %% [markdown]
# Desvio padrão:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='std')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.751395   1.461954
#      48         0.853396   1.693903
#      72         0.769294   1.458600
# D2   24         0.836626   1.044999
#      48         0.836845   1.315476
#      72         0.878041   1.451532

# %% [markdown]
# Valores mínimos:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %% [markdown]
# Valores máximos:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %% [markdown]
# Mediana:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='median')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24          -0.2912    0.02700
#      48          -0.2145    0.01620
#      72          -0.3655    0.02615
# D2   24           0.0096   -0.02610
#      48          -0.0506   -0.02960
#      72           0.0528    0.00015

# %% [markdown]
# Variância:

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='var')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.564594   2.137311
#      48         0.728284   2.869308
#      72         0.591814   2.127514
# D2   24         0.699943   1.092022
#      48         0.700310   1.730477
#      72         0.770956   2.106944

# %% [markdown]
# ###**Desafio 04:**
# Explorar o melt.

# %% [markdown]
# Para isso, vou criar um novo conjunto de dados (aplicar_melt).

# %%
aplicar_melt = pd.DataFrame(dados.groupby(by = 'tratamento')[['g-0', 'g-1', 'g-2']].count())

# %%
aplicar_melt.reset_index(inplace = True)

# %%
aplicar_melt
# Out:
#      tratamento    g-0    g-1    g-2
# 0  com_controle   1866   1866   1866
# 1     com_droga  21948  21948  21948

# %% [markdown]
# O melt atua transformando as colunas em valores de linhas individuais, exceto a coluna que passarmos para o parâmetro em id_vars.

# %%
melted = pd.melt(aplicar_melt, id_vars= 'tratamento')

# %%
melted
# Out:
#      tratamento variable  value
# 0  com_controle      g-0   1866
# 1     com_droga      g-0  21948
# 2  com_controle      g-1   1866
# 3     com_droga      g-1  21948
# 4  com_controle      g-2   1866
# 5     com_droga      g-2  21948

# %% [markdown]
# ###**Desafio 05:**
# Calcular e analisar a correlação entre os G e C. (Dica: perceber que está sendo plotada uma matriz quadrada e definir como fazer o heatmap disso). Refletir sobre os efeitos biológicos.

# %%
dados_g_c_controle = dados.query('tratamento == "com_controle"').loc[:, 'g-0':'c-99']

# %%
dados_g_c_controle_corr = dados_g_c_controle.corr()

# %%
dados_g_c_controle_corr_fatiado = dados_g_c_controle_corr.iloc[0:51 , 772:823]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(dados_g_c_controle_corr_fatiado, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(dados_g_c_controle_corr_fatiado, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# No grupo de controle, por conta de ser ministrado placebo, a correlação entre os nossos G e C é baixa, assim, as células seguem seu comportamento normal, o que não influencia a viabilidade celular de forma direta.

# %%
dados_g_c_droga = dados.query('tratamento == "com_droga"').loc[:, 'g-0':'c-99']

# %%
dados_g_c_droga_corr = dados_g_c_droga.corr()

# %%
dados_g_c_droga_corr_fatiado = dados_g_c_droga_corr.iloc[0:51, 772:823]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(dados_g_c_droga_corr_fatiado, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(dados_g_c_droga_corr_fatiado, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Já quando as células são expostas aos compostos, podemos notar aumento das correlações e até uma frequência no comportamento da viabilidade das células, conforme os compostos.

# %% [markdown]
# ###**Desafio 06:**
# Estudar o código que plota a matriz de correlação (heatmap).

# %% [markdown]
# Basicamente, o código trabalha em 2 fases, na primeira: segmenta os dados acima da diagonal principal; na segunda: converte todos os valores para 1.
# Assim, o heatmap entende onde deve ou não aplicar a máscara (somente para valores divergentes de 1).

# %% [markdown]
# ###**Desafio 07:**
# Resumo do que você aprendeu com os dados.

# %% [markdown]
# Nesta aula pude aprender diversas formas de correlacionar os dados (como scatterplot, lmplot, corr e heatmap).
#
# Assim como, por mais que alguns dados tenham correlação entre si, não necessariamente possuem causalidade, pode ser que tenha algum fator gerando esse efeito.

# %% [markdown]
# #**Aula 04**
# Merge de Dados e Análise de resultados

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis=1)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on = 'id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 25     id_0054388ec  com_controle     48   D1  ...  0.8976  1.0050      0      False
# 38     id_0079af0fb  com_controle     24   D1  ...  0.6498 -1.4820      0      False
# 40     id_007bfbb91  com_controle     24   D2  ...  0.8543  0.9180      0      False
# 47     id_008a986b7  com_controle     48   D2  ... -0.9245 -0.9367      0      False
# 63     id_009d8340f  com_controle     24   D2  ... -0.4326  0.9364      0      False
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ... -0.2422  0.0457      0      False
# 23747  id_ff469c482  com_controle     72   D1  ... -0.0742 -0.6777      0      False
# 23768  id_ff89331ca  com_controle     72   D2  ... -0.1748 -0.3626      0      False
# 23793  id_ffd26f361  com_controle     48   D2  ... -0.5272  0.7082      0      False
# ...

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# ###Aula 04
#
# ###Desafio 01: Encontrar o top 10 das ações do MOA (sufixo inhibitor, antagonist e etc) (Dica: trabalhar com strings)
#
# ###Desafio 02: Criar a coluna 'eh_controle' para quando a linha tratamento == com_controle
#
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72
#
# ###Desafio 04: Estudar sobre combinações de DataFrames (https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
#
# ###Desafio 05: Fazer análise mais detalhada, considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com o controle)
#
# ###Desafio 06: Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa ou não ativa algum MOA
#
# ###Desafio 07: Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa MOAs diferentes
#
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# ###**Desafio 01:**
# Encontrar o top 10 das ações do MOA (sufixo inhibitor, antagonist e etc) (Dica: trabalhar com strings).

# %%
contagem_moa_string = pd.DataFrame(dados_resultados.iloc[:, 1:].sum())

# %%
contagem_moa_string.reset_index(inplace=True)

# %%
contagem_moa_string.drop(index = [206,207], inplace = True)

# %%
contagem_moa_string.columns = ['contagem_moa', 'soma']

# %%
contagem_moa_string['lista'] = contagem_moa_string.contagem_moa.str.split(pat = '_')
contagem_moa_string
# Out:
#                               contagem_moa  ...                                       lista
# 0              5-alpha_reductase_inhibitor  ...             [5-alpha, reductase, inhibitor]
# 1                   11-beta-hsd1_inhibitor  ...                   [11-beta-hsd1, inhibitor]
# 2                           acat_inhibitor  ...                           [acat, inhibitor]
# 3           acetylcholine_receptor_agonist  ...          [acetylcholine, receptor, agonist]
# 4        acetylcholine_receptor_antagonist  ...       [acetylcholine, receptor, antagonist]
# ..                                     ...  ...                                         ...
# 201  ubiquitin_specific_protease_inhibitor  ...  [ubiquitin, specific, protease, inhibitor]
# 202                        vegfr_inhibitor  ...                          [vegfr, inhibitor]
# 203                              vitamin_b  ...                                [vitamin, b]
# ...

# %%
contagem_moa_string['MOA'] = contagem_moa_string.lista.str.get(-1)
contagem_moa_string
# Out:
#                               contagem_moa  ...         MOA
# 0              5-alpha_reductase_inhibitor  ...   inhibitor
# 1                   11-beta-hsd1_inhibitor  ...   inhibitor
# 2                           acat_inhibitor  ...   inhibitor
# 3           acetylcholine_receptor_agonist  ...     agonist
# 4        acetylcholine_receptor_antagonist  ...  antagonist
# ..                                     ...  ...         ...
# 201  ubiquitin_specific_protease_inhibitor  ...   inhibitor
# 202                        vegfr_inhibitor  ...   inhibitor
# 203                              vitamin_b  ...           b
# 204             vitamin_d_receptor_agonist  ...     agonist
# 205                          wnt_inhibitor  ...   inhibitor
#
# [206 rows x 4 columns]

# %%
contagem_moa_final = contagem_moa_string.groupby(by = 'MOA')['soma'].sum().sort_values(ascending = False).reset_index()
contagem_moa_final
# Out:
#                   MOA  soma
# 0           inhibitor  9693
# 1          antagonist  3449
# 2             agonist  2330
# 3             blocker   323
# 4               agent   150
# 5           activator   115
# 6               local    80
# 7   immunosuppressant    73
# 8   anti-inflammatory    73
# 9         antioxidant    73
# 10             medium    56
# 11         sensitizer    51
# 12          stimulant    49
# 13         antibiotic    43
# 14      antiprotozoal    36
# 15         antifolate    36
# 16       secretagogue    30
# 17              donor    26
# 18                  b    26
# 19          antiviral    23
# 20       antimalarial    18
# 21          scavenger    18
# 22         antifungal    13
# 23      antihistamine    12
# 24          analgesic    12
# 25     anticonvulsant    12
# 26     antiarrhythmic     6
# 27           diuretic     6
# 28           laxative     6
# 29            steroid     6

# %%
top_10 = contagem_moa_final['MOA'].value_counts().index[:10]

sns.set()
plt.figure(figsize=(20, 14))
ax = sns.barplot(x='MOA', y='soma', data=contagem_moa_final.query('MOA in @top_10'))
ax.set_title('Top 10 Compostos')
plt.show()

# %% [markdown]
# ###**Desafio 02:**
# Criar a coluna 'eh_controle' para quando a linha tratamento == com_controle

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados['eh_controle'].value_counts()
# Out:
# False    21948
# True      1866
# Name: eh_controle, dtype: int64

# %% [markdown]
# ###**Desafio 03:**
# Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %%
dados_combinados['24'] = (dados_combinados['tempo'] == 24)
dados_combinados['24'].value_counts()
# Out:
# False    16042
# True      7772
# Name: 24, dtype: int64

# %%
dados_combinados['48'] = (dados_combinados['tempo'] == 48)
dados_combinados['48'].value_counts()
# Out:
# False    15564
# True      8250
# Name: 48, dtype: int64

# %%
dados_combinados['72'] = (dados_combinados['tempo'] == 72)
dados_combinados['72'].value_counts()
# Out:
# False    16022
# True      7792
# Name: 72, dtype: int64

# %%
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ... eh_controle     24     48     72
# 0      id_000644bb2     com_droga     24   D1  ...       False   True  False  False
# 1      id_000779bfc     com_droga     72   D1  ...       False  False  False   True
# 2      id_000a6266a     com_droga     48   D1  ...       False  False   True  False
# 3      id_0015fd391     com_droga     48   D1  ...       False  False   True  False
# 4      id_001626bd3     com_droga     72   D2  ...       False  False  False   True
# ...             ...           ...    ...  ...  ...         ...    ...    ...    ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...       False   True  False  False
# 23810  id_fffb70c0c     com_droga     24   D2  ...       False   True  False  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True  False   True  False
# 23812  id_fffcb9e7c     com_droga     24   D1  ...       False   True  False  False
# ...

# %% [markdown]
# ###**Desafio 04:**
# Estudar sobre combinações de DataFrames (https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)

# %% [markdown]
# ###**Desafio 05:**
# Fazer análise mais detalhada, considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com o controle)

# %%
dados_combinados.query('n_moa != 0').composto.value_counts()
# Out:
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# 861a693e3      1
# 4055d26a8      1
# 161572520      1
# a90e40334      1
# 06787fefe      1
# Name: composto, Length: 2076, dtype: int64

# %% [markdown]
# Para nossa comparação, selecionei o composto que apareceu mais vezes como Mecanismos de Ação (n_moa), no caso, o 87d714366, por conta de termos mais amostras para observar.

# %%
composto = sns.FacetGrid(dados_combinados.query('composto == "87d714366"'), row = 'dose', col = 'tempo', hue = 'tratamento')
composto = composto.map_dataframe(sns.histplot, x = 'g-0')

# %% [markdown]
# Abaixo, temos a ação do grupo de controle:

# %%
controle = sns.FacetGrid(dados_combinados.query('tratamento == "com_controle"'), row = 'dose', col = 'tempo', hue = 'tratamento')
controle = controle.map_dataframe(sns.histplot, x = 'g-0')

# %%
dados_composto = dados_combinados.query('composto == "87d714366"')
dados_controle = dados_combinados.query('tratamento == "com_controle"')
composto_controle_concatenados = pd.concat([dados_composto, dados_controle], axis = 0)

# %%
grafico = sns.FacetGrid(composto_controle_concatenados, row = 'dose', col = 'tempo', hue = 'tratamento')
grafico = grafico.map_dataframe(sns.histplot, x = 'g-0', kde = True)
grafico.add_legend()

# %% [markdown]
# Com isso, podemos observar que o gene g-0 tem uma tendência a apresentar maior expressão quando exposto ao composto selecionado (87d714366) e que em todos os cenários apresentados, essa alteração foi positiva (eixo y).

# %% [markdown]
# ###**Desafio 06:**
# Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
ativos = dados_combinados.groupby(by='composto')['ativo_moa'].nunique()
ativos
# Out:
# composto
# 00199ff52    1
# 00251fc41    1
# 00321ea80    1
# 0034c0847    1
# 0060e686f    1
#             ..
# ff9565933    1
# ffd66e220    1
# ffe357f8f    1
# ffed8e1c9    1
# fff7d208d    1
# Name: ativo_moa, Length: 3289, dtype: int64

# %%
contador = 0
for i in range(len(ativos)):
  if ativos[i] == 1:
    pass
  else:
    count += 1
    print(ativos[i].index)

if contador == 0:
  print('Todos os compostos apresentam somente um MOA')
else:
  pass
# Out:
# Todos os compostos apresentam somente um MOA

# %% [markdown]
# ###**Desafio 07:**
# Descobrir se temos algum composto que, dependendo da configuração do experimento, ativa MOAs diferentes

# %% [markdown]
# Com o desafio anterior, descobrimos que todos os compostos apresentam apenas 1 MOA

# %% [markdown]
# ###**Desafio 08:**
# Resumo do que você aprendeu com os dados

# %% [markdown]
# Com a Aula 04 entendi que o merge funciona de forma similar ao JOIN utilizado em Bancos de Dados SQL e, através dele, pude comparar o comportamento de cada um dos diferentes compostos apresentados relacionados a cada um dos genes.
#
# Avaliamos quais compostos possuem maior Mecanismo de Ação (na pesquisa avaliada), ordenando-os de forma decrescente.
#
# A partir dessas informações, analisamos o comportamento do composto com maior número de interações gênicas, relacionado ao tempo após aplicação. Também fizemos a mesma análise com o grupo de controle (placebo) e em seguida, concatenamos estes dados para melhor visualização no Desafio 05.

# %% [markdown]
# ###Aula 05

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y , random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize = True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y , random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import  tree

fig, ax = plt.subplots(figsize = (15,10), facecolor = 'k')

tree.plot_tree(modelo_arvore,
               ax = ax,
               fontsize = 10,
               rounded = True,
               filled = True,
               feature_names = x_treino.columns,
               class_names = ['Não Ativado', 'Ativado'])
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y , random_state=376)

teste=[]
treino=[]
for i in range(1,15):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    treino.append(modelo_arvore.score(x_treino, y_treino))
    teste.append(modelo_arvore.score(x_teste, y_teste))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6204073063195465,
#  0.6208272097417594,
#  0.6178878857862692,
#  0.6212471131639723,
#  0.6214570648750787,
#  0.6170480789418433,
#  0.6145286584085661,
#  0.6096997690531177,
#  0.5979424732311568,
#  0.5983623766533698,
#  0.5975225698089439]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6606477350270327,
#  0.6707259461445594,
#  0.6895176106241142,
#  0.7069445173481707,
#  0.7293580389480867,
#  0.7529788462547897,
#  0.7770195790247231,
#  0.7992756285759278]

# %%
sns.lineplot(x = range(1,15), y = teste, label = 'teste')
sns.lineplot(x = range(1,15), y = treino, label = 'treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y , random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6869619987402897

# %% [markdown]
# ###Aula 05
#
# ###Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.
#
# ###Desafio 02: Estude a documentação do Sklearn.
#
# ###Desafio 03: Pesquisar o fluxograma escolhendo o melhor modelo (pesquisar "Choosing the right estimator" no Google)
#
# ###Desafio 04: Teste outros problemas (perguntas). 0, 1 ou +.
#
# ###Desafio 05: Escolha a droga mais utilizada e tente criar um modelo para prever esta label (se é um caso de controle ou de composto).
#
# ###Desafio 06: Resumo do que você aprendeu com os dados.

# %% [markdown]
# ###**Desafio 01:**
# Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

# %% [markdown]
# De acordo com o que vimos em aula, para gerar a profundidade 15 para a DecisionTreeClassifier, apliquei a mesma lógica da repetição para chegarmos em árvores com profundidade 10 e 15 utilizando RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y , random_state=376)

teste=[]
treino=[]
for i in range(1,10):
    modelo_randomforest = RandomForestClassifier(max_depth=i)
    modelo_randomforest.fit(x_treino, y_treino)
    treino.append(modelo_randomforest.score(x_treino, y_treino))
    teste.append(modelo_randomforest.score(x_teste, y_teste))

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6848459398456774,
#  0.6850034118943887,
#  0.6899900267702482,
#  0.6920896540863997,
#  0.6936643745735132,
#  0.6965513621332213,
#  0.6995958217416408,
#  0.7035851136423285]

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6833928196514801,
#  0.6833928196514801,
#  0.6867520470291832,
#  0.6878018055847155,
#  0.688011757295822,
#  0.688011757295822,
#  0.6892714675624606,
#  0.6882217090069284]

# %%
sns.lineplot(x = range(1,10), y = treino, label = 'treino')
sns.lineplot(x = range(1,10), y = teste, label = 'teste')

# %% [markdown]
# Abaixo, faço os testes com profundidade 15:

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y , random_state=376)

teste=[]
treino=[]
for i in range(1,10):
    modelo_randomforest = RandomForestClassifier(max_depth=i)
    modelo_randomforest.fit(x_treino, y_treino)
    treino.append(modelo_randomforest.score(x_treino, y_treino))
    teste.append(modelo_randomforest.score(x_teste, y_teste))

# %%
treino

# %%
teste

# %%
sns.lineplot(x = range(1,15), y = treino, label = 'treino')
sns.lineplot(x = range(1,15), y = teste, label = 'teste')

# %% [markdown]
# Conforme o Fluxograma para escolher o estimador correto, da [Documentação do SKlearn](https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html), segui para o uso do [SVC](https://scikit-learn.org/stable/modules/svm.html#classification):

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(x_treino, y_treino)
clf.score(x_teste, y_teste)

# %% [markdown]
# ###**Desafio 02:**
# Estude a Documentação do SKlearn.

# %% [markdown]
# Através dela, consegui fazer uso do SVC no exercício anterior.

# %% [markdown]
# ###**Desafio 03:**
# Pesquisar o fluxograma escolhendo o melhor modelo.

# %% [markdown]
# Conforme a Documentação do SKlearn, com o fluxoframa para definir o estimador correto, cheguei na decisão de também utilizar o SVC no Desafio 01.

# %% [markdown]
# ###**Desafio 04:**
# Teste outros problemas (perguntas). 0, 1 ou +.

# %% [markdown]
# ###**Desafio 05:**
# Escolha a droga mais utilizada e tente criar um modelo para prever esta label (se é um caso de controle ou de composto).

# %% [markdown]
# ###**Desafio 06:**
# Resumo do que você aprendeu com os dados.

# %% [markdown]
# Na aula de hoje, pude ver alguns conceitos de Machine Learning, e fui apresentado à biblioteca SKlearn.
#
# Através dessa biblioteca, utilizamos os métodos de estimativa Logisticregression, DecisionTreeClassifier e RandomForestClassifier, além do uso do DummyClassifier, para testes de cenários com métodos pouco definidos (como por exemplo "chutar" que sempre aparecerá o valor de maior frequência, conforme visto em aula).
